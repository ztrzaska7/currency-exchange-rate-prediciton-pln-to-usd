# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.style.use('dark_background')
data=pd.read_csv('PLN=X.csv')
print(data.head())
# Out:
#          Date      Open      High       Low     Close  Adj Close  Volume
# 0  2023-05-03  4.156695  4.158738  4.138400  4.156695   4.156695       0
# 1  2023-05-04  4.145050  4.170643  4.131158  4.145050   4.145050       0
# 2  2023-05-05  4.160308  4.172070  4.144233  4.160308   4.160308       0
# 3  2023-05-08  4.148080  4.149669  4.128500  4.148080   4.148080       0
# 4  2023-05-09  4.147157  4.175754  4.142720  4.147157   4.147157       0

# %%
plt.figure(figsize=(15,10))
plt.title('PLN to US Dollar Exchange rate')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.plot(data['Close'])
plt.show()

# %%
x=data[['High','Open','Low']]
y=data['Close']
x=x.to_numpy()
y=y.to_numpy()
y=y.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(xtrain,ytrain)
pred=model.predict(xtest)

# %%
data=pd.DataFrame(data={'Predicted data':pred.flatten()})
print(data.head())
# Out:
#    Predicted data
# 0        4.259582
# 1        4.170128
# 2        4.030400
# 3        3.914948
# 4        4.055636
